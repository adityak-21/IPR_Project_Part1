# %%
# !pip install torch torchvision opencv-python pyyaml
# Out:
# Requirement already satisfied: torch in c:\python312\lib\site-packages (2.4.0+cu118)
# Requirement already satisfied: torchvision in c:\python312\lib\site-packages (0.19.0+cu118)
# Requirement already satisfied: opencv-python in c:\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: pyyaml in c:\python312\lib\site-packages (6.0.1)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: setuptools in c:\python312\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt --user
# Out:
# c:\Users\Tejaswa\Downloads\Aditya\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# C:\Users\Tejaswa\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in c:\python312\lib\site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 9)) (11.0.0)
# Requirement already satisfied: psutil in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 10)) (5.9.8)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 12)) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 15)) (2.4.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 16)) (0.19.0+cu118)
# Requirement already satisfied: tqdm>=4.66.3 in c:\python312\lib\site-packages (from -r requirements.txt (line 17)) (4.66.4)
# Requirement already satisfied: ultralytics>=8.2.34 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 18)) (8.2.85)
# Requirement already satisfied: pandas>=1.1.4 in c:\python312\lib\site-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 42)) (72.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.5.0)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\python312\lib\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %cd ..
# Out:
# c:\Users\Tejaswa\Downloads\Aditya

# %%
import os
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class VEDAIDataset(Dataset):
    def __init__(self, img_dir, label_dir, img_size=640, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.img_size = img_size
        self.image_files = sorted([f for f in os.listdir(self.img_dir) if f.endswith("_co.png")])
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        rgb_img_path = os.path.join(self.img_dir, self.image_files[idx])
        ir_img_path = rgb_img_path.replace("_co.png", "_ir.png")
        label_path = os.path.join(self.label_dir, self.image_files[idx].replace("_co.png", ".txt"))

        rgb_img = cv2.imread(rgb_img_path)
        ir_img = cv2.imread(ir_img_path, cv2.IMREAD_GRAYSCALE)

        if rgb_img is None or ir_img is None:
            raise FileNotFoundError(f"Image file not found: {rgb_img_path} or {ir_img_path}")

        boxes = self.load_labels(label_path)

        rgb_img = cv2.resize(rgb_img, (self.img_size, self.img_size))
        ir_img = cv2.resize(ir_img, (self.img_size, self.img_size))
        ir_img = cv2.merge([ir_img, ir_img, ir_img])

        # rgb_img = rgb_img / 255.0
        # ir_img = ir_img / 255.0

        img = torch.cat([torch.tensor(rgb_img).permute(2, 0, 1), torch.tensor(ir_img).permute(2, 0, 1)], dim=0)  # [6, H, W]

        # if self.transform:
        #     img = self.transform(img)
        img = img.float()/255.0

        return img, boxes

    def load_labels(self, label_path):
        boxes = []
        with open(label_path, "r") as f:
            for line in f:
                parts = line.strip().split()
                boxes.append([float(p) for p in parts])
        return torch.tensor(boxes)
    
data_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor()
])

train_data = VEDAIDataset(img_dir="images-Aditya\\images\\train", label_dir="labels-Aditya\\labels\\train", img_size=640)

# %%
def collate_fn(batch):
    imgs, targets = [], []

    for sample in batch:
        imgs.append(sample[0])
        targets.append(sample[1])

    imgs = torch.stack(imgs, 0)

    return imgs, targets

train_loader = DataLoader(train_data, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
import torch
import torch.nn as nn

class DifferentialEnhanciveModule(nn.Module):
    def __init__(self, in_channels):
        super(DifferentialEnhanciveModule, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.global_max_pool = nn.AdaptiveMaxPool2d(1)
        self.fc1 = nn.Conv2d(in_channels, in_channels // 16, kernel_size=1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Conv2d(in_channels // 16, in_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, diff_feat):
        avg_pool = self.global_avg_pool(diff_feat)
        max_pool = self.global_max_pool(diff_feat)
        attention = self.fc1(avg_pool + max_pool)
        attention = self.relu(attention)
        attention = self.fc2(attention)
        attention = self.sigmoid(attention)
        enhanced_diff_feat = diff_feat * (1 + attention)
        return enhanced_diff_feat

class CommonSelectiveModule(nn.Module):
    def __init__(self, in_channels):
        super(CommonSelectiveModule, self).__init__()
        self.fc1 = nn.Conv2d(in_channels, in_channels // 16, kernel_size=1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Conv2d(in_channels // 16, in_channels, kernel_size=1)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, common_feat):
        attention = self.fc1(common_feat)
        attention = self.relu(attention)
        attention = self.fc2(attention)
        attention = self.softmax(attention)
        refined_common_feat = common_feat * attention
        return refined_common_feat

class CMAFF(nn.Module):
    def __init__(self, in_channels=512):
        super(CMAFF, self).__init__()
        self.differential_module = DifferentialEnhanciveModule(in_channels)
        self.common_module = CommonSelectiveModule(in_channels)
        self.conv1x1 = nn.Conv2d(in_channels * 2, in_channels, kernel_size=1)

    def forward(self, rgb_feat, ir_feat):
        common_feat = (rgb_feat + ir_feat) / 2
        refined_common_feat = self.common_module(common_feat)
        diff_feat = (rgb_feat - ir_feat) / 2
        enhanced_diff_feat = self.differential_module(diff_feat)
        combined_feat = torch.cat((refined_common_feat, enhanced_diff_feat), dim=1)
        fused_feat = self.conv1x1(combined_feat)
        return fused_feat

class YOLOv5WithCMAFF(nn.Module):
    def __init__(self, yolo_model):
        super(YOLOv5WithCMAFF, self).__init__()
        self.backbone = yolo_model.model.model.model[:10]  # Use the first part of the YOLOv5 backbone for RGB features
        self.ir_conv = nn.Conv2d(1, 512, kernel_size=3, stride=1, padding=1)  # Conv layer for IR
        self.ir_downsample = nn.MaxPool2d(kernel_size=32, stride=32)
        self.cmaff = CMAFF(512)

        self.head = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1)
        )

    def forward(self, img):
        rgb_img, ir_img = img[:, :3, :, :], img[:, 3:4, :, :]  # Ensure IR is single-channel

        # Process IR image: Convert to grayscale, apply histogram equalization, convert back to float
        ir_img_equalized = []
        for i in range(ir_img.size(0)):
            ir_gray = ir_img[i].squeeze(0)  # Remove channel dimension temporarily for processing
            ir_gray = (ir_gray * 255).clamp(0, 255).byte()  # Scale and convert to uint8
            ir_equalized = cv2.equalizeHist(ir_gray.cpu().numpy())  # Apply equalization
            ir_equalized = torch.tensor(ir_equalized).unsqueeze(0).float().div(255.0).to(img.device)  # Convert to float
            ir_img_equalized.append(ir_equalized)

        ir_img = torch.stack(ir_img_equalized, dim=0)  # Combine equalized images into a batch with single channel

        # Extract features for RGB channels using the backbone
        rgb_feat = self.backbone(rgb_img)
        # Process IR features separately
        ir_feat = self.ir_conv(ir_img)  # Single-channel input for IR
        ir_feat = self.ir_downsample(ir_feat)

        # Fuse the features using CMAFF
        fused_feat = self.cmaff(rgb_feat, ir_feat)
        
        # Pass through the head layers
        for i, layer in enumerate(self.head):
            fused_feat = layer(fused_feat)
        return fused_feat

    
from yolov5.models.yolo import Model
# yolo_model = Model(cfg='yolov5//models//yolov5s.yaml', ch=3, nc=80)
# model = YOLOv5WithCMAFF(yolo_model)
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model = YOLOv5WithCMAFF(yolo_model).to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
# Out:
# Using cache found in C:\Users\Tejaswa/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  v7.0-376-gbcd88eaf Python-3.12.3 torch-2.4.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
for param in model.backbone.parameters():
    param.requires_grad = False
import torch
import torch.optim as optim
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)
classification_loss_fn = nn.BCEWithLogitsLoss()
bbox_loss_fn = nn.SmoothL1Loss()
confidence_loss_fn = nn.BCEWithLogitsLoss()

num_classes = 80
grid_size = (5, 5)

num_epochs = 20
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for imgs, targets in train_loader:
        imgs = imgs.to(device).float()

        optimizer.zero_grad()

        
        outputs = model(imgs)
        print(f"Model output type: {type(outputs)}, output shape: {outputs.shape}")

        class_preds = outputs[:, :num_classes, :, :]
        bbox_preds = outputs[:, num_classes:, :, :]

        bbox_coords_preds = bbox_preds[:, :4, :, :]
        conf_preds = bbox_preds[:, 4:, :, :]

        batch_classification_loss = 0.0
        batch_bbox_loss = 0.0
        batch_confidence_loss = 0.0

        for i, target in enumerate(targets):
            class_target = target[:, 0]
            bbox_target = target[:, 1:].to(device)

            bbox_target_grid = torch.zeros_like(bbox_coords_preds[i])
            class_target_grid = torch.zeros((num_classes, *grid_size)).to(device)

            for obj in target:
                class_label = int(obj[0])
                bbox = obj[1:]

                grid_x = int(bbox[0] * grid_size[0])
                grid_y = int(bbox[1] * grid_size[1])

                grid_x = min(grid_x, grid_size[0] - 1)
                grid_y = min(grid_y, grid_size[1] - 1)

                class_target_grid[class_label, grid_x, grid_y] = 1
                bbox_target_grid[:, grid_x, grid_y] = bbox


            classification_loss = classification_loss_fn(class_preds[i], class_target_grid)

            bbox_loss = bbox_loss_fn(bbox_coords_preds[i], bbox_target_grid)

            confidence_target = torch.ones_like(conf_preds[i]) if target.size(0) > 0 else torch.zeros_like(conf_preds[i])

            confidence_loss = confidence_loss_fn(conf_preds[i], confidence_target)

            print(confidence_loss)

            batch_classification_loss += classification_loss
            batch_bbox_loss += bbox_loss
            batch_confidence_loss += confidence_loss

        total_loss = batch_classification_loss + batch_bbox_loss + batch_confidence_loss

        total_loss.backward()
        optimizer.step()

        running_loss += total_loss.item()
        print(f"Epoch [{epoch+1}/{num_epochs}]")

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader)}")
# Out:
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.69320, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69318, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69316, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69320, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.68752, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68754, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68746, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68760, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.67033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.67104, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.66842, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.66974, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.62661, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.62359, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.62199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.62090, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.51074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.51841, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.51776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.51995, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.34251, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.33140, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.32000, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.33718, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.14850, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.13582, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.13823, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.15971, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.04499, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04247, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05386, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01496, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01249, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01374, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00579, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01001, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00416, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00811, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00472, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00730, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00298, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00502, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00273, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00407, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00339, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00525, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00561, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00342, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00502, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00620, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00688, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00667, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01369, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00650, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00618, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00567, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01217, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01563, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01228, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01779, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01777, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02158, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02590, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02336, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02645, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.04146, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02905, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03970, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03251, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.04883, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04386, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04650, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03913, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.04202, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04521, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04904, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.06016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.06177, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04500, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.04246, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04567, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03504, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05208, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.03800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05919, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05278, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.05694, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02655, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03234, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02891, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02629, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02193, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02192, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02812, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01215, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01083, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01551, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01841, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01137, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01154, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01582, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01102, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00853, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00883, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00563, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00554, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00628, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00678, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00669, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00568, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00491, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00298, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00465, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00416, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00394, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00321, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00311, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00302, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00254, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00212, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00291, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00220, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00123, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00273, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00220, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00134, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00335, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00209, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00357, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00094, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00120, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00249, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00111, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00081, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00120, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00095, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00125, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00091, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00116, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00163, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00103, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00186, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00182, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00077, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00082, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00081, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00200, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00045, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00105, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00096, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00098, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00176, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00088, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00081, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00083, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00088, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00116, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00081, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00092, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00121, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00119, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00119, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00090, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00110, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00088, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00075, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00153, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00318, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00133, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00097, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00115, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00090, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00102, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00143, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00116, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00075, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00154, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00090, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00100, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00129, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00096, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00106, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00075, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00064, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00104, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00110, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00097, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00087, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00093, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00082, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00068, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00056, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00122, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00091, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00096, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00077, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00088, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00056, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00045, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00056, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Epoch [1/20], Loss: 0.45979231807890286
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.74829e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# ...
# tensor(6.32537e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.71082e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.23284e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.69871e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.67014e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00013, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.41515e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.69994e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.44773e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.15896e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.51140e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.21394e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.14973e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.17147e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.63259e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.71018e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.01023e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.64335e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.37264e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.73127e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.13803e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.77128e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.40797e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.94499e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.60553e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.81890e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.28516e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00013, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.68046e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.26917e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(7.36478e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.54263e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.54952e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.83044e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.20934e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.26966e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.02996e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.85397e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.34099e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(6.74780e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.27920e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.80580e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.17262e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.53602e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.04186e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.62784e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.47999e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.88940e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.29742e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.54626e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.16517e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.69364e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.50482e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.05029e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.31967e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.29362e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.15557e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.38211e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.58797e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(8.75714e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.40721e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.05859e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.44743e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.16276e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.14502e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.10229e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.92400e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.42461e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.42633e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.75229e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.65977e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.72204e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.20049e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.51001e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.53366e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.38694e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.31456e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(7.03783e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.69520e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.08263e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.43248e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.54652e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.93022e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.85518e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.71024e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.95120e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.97533e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.97683e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.26653e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.54320e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.61672e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.10640e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.51151e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(6.43604e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.32480e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.83868e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.38303e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(8.25656e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.61773e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.28120e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.76027e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.18233e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.46476e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.28550e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.44659e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.27707e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.89754e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.23838e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.64139e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.19774e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.48853e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.05559e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.06665e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.91703e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.07492e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.86714e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.79224e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.30641e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.69410e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.79985e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.42468e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.62044e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.90580e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(7.31161e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.05950e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.16562e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.10290e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Epoch [20/20], Loss: 0.03764423124765584

# %%
val_data = VEDAIDataset(img_dir="images-Aditya\\images\\val", label_dir="labels-Aditya\\labels\\val", img_size=640)

# %%
val_loader = DataLoader(val_data, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
import torch
from collections import defaultdict
import numpy as np
from sklearn.metrics import precision_recall_curve

def calculate_iou(box1, box2):

    box1_x1 = (box1[0] - box1[2] / 2)
    box1_y1 = (box1[1] - box1[3] / 2)
    box1_x2 = (box1[0] + box1[2] / 2)
    box1_y2 = (box1[1] + box1[3] / 2)
    
    box2_x1 = box2[0] - box2[2] / 2
    box2_y1 = box2[1] - box2[3] / 2
    box2_x2 = box2[0] + box2[2] / 2
    box2_y2 = box2[1] + box2[3] / 2

    inter_x1 = torch.max(box1_x1, box2_x1)
    inter_y1 = torch.max(box1_y1, box2_y1)
    inter_x2 = torch.min(box1_x2, box2_x2)
    inter_y2 = torch.min(box1_y2, box2_y2)
    
    inter_area = max(((inter_x2 - inter_x1)*(inter_y2 - inter_y1)), 0)

    box1_area = (box1_x2 - box1_x1) * (box1_y2 - box1_y1)
    box2_area = (box2_x2 - box2_x1) * (box2_y2 - box2_y1)
    union_area = box1_area + box2_area - inter_area

    iou = (inter_area / (union_area + 1e-6))

    return iou

from torchvision.ops import nms

def apply_nms(predictions, iou_threshold=0.2):
    boxes = predictions[:, :4]
    scores = predictions[:, 4]
    
    keep_indices = nms(boxes, scores, iou_threshold)
    
    return predictions[keep_indices]

def calculate_ap(precision, recall):
    precision = np.concatenate(([0.0], precision, [0.0]))
    recall = np.concatenate(([0.0], recall, [1.0]))

    for i in range(len(precision) - 1, 0, -1):
        precision[i - 1] = max(precision[i - 1], precision[i])

    indices = np.where(recall[1:] != recall[:-1])[0]
    ap = np.sum((recall[indices + 1] - recall[indices]) * precision[indices + 1])
    return ap

def evaluate_model(model, dataloader, iou_threshold=0.1, max_boxes=2):
    model.eval()
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    true_positives_list = []
    scores_list = []
    num_gts = 0

    all_detections = []
    all_ground_truths = []

    with torch.no_grad():
        for imgs, targets in dataloader:
            print(f"precision = ", true_positives / (true_positives + false_positives + 1e-6))
            print(f"recall = ", true_positives / (true_positives + false_negatives + 1e-6))
            p = np.cumsum(true_positives_list) / (np.arange(len(true_positives_list)) + 1)
            r = np.cumsum(true_positives_list) / (num_gts+1)
            print(f"map = ", calculate_ap(p, r))
            imgs = imgs.to(device).float()
            outputs = model(imgs)

            class_preds = outputs[:, :num_classes, :, :]
            bbox_preds = outputs[:, num_classes:, :, :]

            for i, target in enumerate(targets):
                gt_boxes = target[:, 1:]
                pred_boxes = bbox_preds[i].detach().cpu()

                pred_scores = class_preds[i].detach().cpu().view(-1)
                pred_boxes = pred_boxes.view(-1, 4)
                
                if len(pred_scores) > 0:
                    top_indices = torch.topk(pred_scores, min(max_boxes, len(pred_scores))).indices
                    pred_boxes = pred_boxes[top_indices]

                all_ground_truths.append(gt_boxes)
                all_detections.append(pred_boxes)

                matched_gt = set()
                for pred_box in pred_boxes:
                    best_iou = 0
                    best_gt_idx = -1

                    for gt_idx, gt_box in enumerate(gt_boxes):
                        iou = calculate_iou(pred_box, gt_box)
                        iou_value = iou.item()

                        if iou_value > best_iou:
                            best_iou = iou_value
                            best_gt_idx = gt_idx

                    if best_iou > iou_threshold:
                        if best_gt_idx not in matched_gt:
                            true_positives += 1
                            matched_gt.add(best_gt_idx)
                            true_positives_list.append(1)
                    else:
                        false_positives += 1
                        true_positives_list.append(0)

                    scores_list.append(pred_scores[i].item())

                false_negatives += len(gt_boxes) - len(matched_gt)
                num_gts += len(gt_boxes)

    precision = true_positives / (true_positives + false_positives + 1e-6)
    recall = true_positives / (true_positives + false_negatives + 1e-6)

    true_positives_list = np.array(true_positives_list)
    scores_list = np.array(scores_list)

    precisions = np.cumsum(true_positives_list) / (np.arange(len(true_positives_list)) + 1)
    recalls = np.cumsum(true_positives_list) / num_gts

    ap_0_5 = calculate_ap(precisions, recalls)

    return precision, recall, ap_0_5

precision, recall, map_0_5 = evaluate_model(model, val_loader)
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, mAP@0.5: {map_0_5:.4f}")
# Out:
# precision =  0.0
# recall =  0.0
# map =  0.0
# precision =  0.49999991666668053
# recall =  0.10714285331632667
# map =  0.06896551724137931
# precision =  0.699999930000007
# recall =  0.18918918407596802
# map =  0.13684210526315788
# precision =  0.7857142295918408
# recall =  0.2199999956000001
# map =  0.17366946778711484
# precision =  0.7368420664819965
# recall =  0.21874999658203131
# map =  0.17027183342972815
# precision =  0.7083333038194456
# recall =  0.24637680802352452
# map =  0.18962585034013604
# precision =  0.7241379060642101
# recall =  0.2692307657790928
# map =  0.2070524412296564
# precision =  0.7352940960207619
# recall =  0.2604166639539931
# map =  0.20065158209488104
# precision =  0.7631578746537402
# recall =  0.2566371658704676
# map =  0.19819285054742117
# precision =  0.7674418426176316
# recall =  0.2519083950236
# map =  0.197082035000356
# precision =  0.7142856997084551
# recall =  0.2536231865679479
# map =  0.19743453272387354
# precision =  0.7222222088477369
# recall =  0.24683544147572506
# map =  0.19095115628179352
# precision =  0.7413792975624259
# recall =  0.24999999854651164
# map =  0.1932290273034409
# precision =  0.7460317341899725
# recall =  0.26553672166363435
# map =  0.2050948995062387
# precision =  0.7499999889705884
# recall =  0.24999999877450982
# map =  0.19338349511626768
# precision =  0.753424647213361
# recall =  0.2522935768243414
# map =  0.19479971163584112
# precision =  0.7564102467126892
# recall =  0.2633928559669962
# map =  0.2031261680382498
# precision =  0.7380952293083901
# recall =  0.26609441945882223
# map =  0.20511687269299797
# precision =  0.7333333251851853
# recall =  0.27160493715388917
# map =  0.20897591496398543
# precision =  0.718749992513021
# recall =  0.2738095227229781
# map =  0.21019466476721532
# precision =  0.6960784245482508
# recall =  0.2699619761598404
# map =  0.20681771813087196
# precision =  0.700934572888462
# recall =  0.27573529310391437
# map =  0.21028744341528913
# precision =  0.6964285652104593
# recall =  0.27464788635687365
# map =  0.20904044360668406
# precision =  0.6864406721488079
# recall =  0.277397259323982
# map =  0.2104853010112309
# precision =  0.6854838654396462
# recall =  0.28239202563989363
# map =  0.21336967003563642
# precision =  0.6953124945678711
# recall =  0.2880258890355149
# map =  0.2168861070848086
# precision =  0.6992481150432472
# recall =  0.29430379653701333
# map =  0.2211603647221072
# precision =  0.7028985456311699
# recall =  0.2895522379416351
# map =  0.21709906694142017
# precision =  0.6944444396219136
# recall =  0.27932960815829716
# map =  0.2090361734147926
# precision =  0.6979865724967345
# recall =  0.2833787458218563
# map =  0.21154959097033335
# precision =  0.7012986967448137
# recall =  0.28647214778124097
# map =  0.2133894976803027
# precision =  0.7088607550072105
# recall =  0.29166666590711804
# map =  0.21734491493685645
# precision =  0.7116564373518011
# recall =  0.2914572856998561
# map =  0.21764930015066647
# precision =  0.7185628699487253
# recall =  0.2836879425917543
# map =  0.2118677897824352
# precision =  0.7209302283666847
# recall =  0.28571428505595786
# map =  0.213411567157051
# precision =  0.7231638377222382
# recall =  0.2857142850765306
# map =  0.21360095293924566
# precision =  0.7252747212896994
# recall =  0.28820960635762094
# map =  0.21542065926729387
# precision =  0.7311827917678345
# recall =  0.2899786774200881
# map =  0.2174062346673029
# precision =  0.7368421013850416
# recall =  0.2880658430286711
# map =  0.21667340413268155
# precision =  0.7422680374109895
# recall =  0.2857142851473923
# map =  0.2156355746051704
# precision =  0.7474747436996225
# recall =  0.28352490367140826
# map =  0.21472071799569564
# Precision: 0.7487, Recall: 0.2849, mAP@0.5: 0.2164
