# %%
# !pip install torch torchvision opencv-python pyyaml
# Out:
# Requirement already satisfied: torch in c:\python312\lib\site-packages (2.4.0+cu118)
# Requirement already satisfied: torchvision in c:\python312\lib\site-packages (0.19.0+cu118)
# Requirement already satisfied: opencv-python in c:\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: pyyaml in c:\python312\lib\site-packages (6.0.1)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: setuptools in c:\python312\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt --user
# Out:
# c:\Users\Tejaswa\Downloads\Aditya\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in c:\python312\lib\site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 9)) (11.0.0)
# Requirement already satisfied: psutil in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 10)) (5.9.8)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 12)) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\python312\lib\site-packages (from -r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 15)) (2.4.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 16)) (0.19.0+cu118)
# Requirement already satisfied: tqdm>=4.66.3 in c:\python312\lib\site-packages (from -r requirements.txt (line 17)) (4.66.4)
# Requirement already satisfied: ultralytics>=8.2.34 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 18)) (8.2.85)
# Requirement already satisfied: pandas>=1.1.4 in c:\python312\lib\site-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\python312\lib\site-packages (from -r requirements.txt (line 42)) (72.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python312\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.5.0)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\python312\lib\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\tejaswa\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %cd ..
# Out:
# c:\Users\Tejaswa\Downloads\Aditya

# %%
import os
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class VEDAIDataset(Dataset):
    def __init__(self, img_dir, label_dir, img_size=640, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.img_size = img_size
        self.image_files = sorted([f for f in os.listdir(self.img_dir) if f.endswith("_co.png")])
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        rgb_img_path = os.path.join(self.img_dir, self.image_files[idx])
        ir_img_path = rgb_img_path.replace("_co.png", "_ir.png")
        label_path = os.path.join(self.label_dir, self.image_files[idx].replace("_co.png", ".txt"))

        rgb_img = cv2.imread(rgb_img_path)
        ir_img = cv2.imread(ir_img_path, cv2.IMREAD_GRAYSCALE)

        if rgb_img is None or ir_img is None:
            raise FileNotFoundError(f"Image file not found: {rgb_img_path} or {ir_img_path}")

        boxes = self.load_labels(label_path)

        rgb_img = cv2.resize(rgb_img, (self.img_size, self.img_size))
        ir_img = cv2.resize(ir_img, (self.img_size, self.img_size))
        ir_img = cv2.merge([ir_img, ir_img, ir_img])

        # rgb_img = rgb_img / 255.0
        # ir_img = ir_img / 255.0

        img = torch.cat([torch.tensor(rgb_img).permute(2, 0, 1), torch.tensor(ir_img).permute(2, 0, 1)], dim=0)  # [6, H, W]

        # if self.transform:
        #     img = self.transform(img)
        img = img.float()/255.0

        return img, boxes

    def load_labels(self, label_path):
        boxes = []
        with open(label_path, "r") as f:
            for line in f:
                parts = line.strip().split()
                boxes.append([float(p) for p in parts])
        return torch.tensor(boxes)
    
data_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor()
])

train_data = VEDAIDataset(img_dir="images-Aditya\\images\\train", label_dir="labels-Aditya\\labels\\train", img_size=640)

# %%
def collate_fn(batch):
    imgs, targets = [], []

    for sample in batch:
        imgs.append(sample[0])
        targets.append(sample[1])

    imgs = torch.stack(imgs, 0)

    return imgs, targets

train_loader = DataLoader(train_data, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
import torch
import torch.nn as nn

class DifferentialEnhanciveModule(nn.Module):
    def __init__(self, in_channels):
        super(DifferentialEnhanciveModule, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.global_max_pool = nn.AdaptiveMaxPool2d(1)
        self.fc1 = nn.Conv2d(in_channels, in_channels // 16, kernel_size=1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Conv2d(in_channels // 16, in_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, diff_feat):
        avg_pool = self.global_avg_pool(diff_feat)
        max_pool = self.global_max_pool(diff_feat)
        attention = self.fc1(avg_pool + max_pool)
        attention = self.relu(attention)
        attention = self.fc2(attention)
        attention = self.sigmoid(attention)
        enhanced_diff_feat = diff_feat * (1 + attention)
        return enhanced_diff_feat

class CommonSelectiveModule(nn.Module):
    def __init__(self, in_channels):
        super(CommonSelectiveModule, self).__init__()
        self.fc1 = nn.Conv2d(in_channels, in_channels // 16, kernel_size=1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Conv2d(in_channels // 16, in_channels, kernel_size=1)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, common_feat):
        attention = self.fc1(common_feat)
        attention = self.relu(attention)
        attention = self.fc2(attention)
        attention = self.softmax(attention)
        refined_common_feat = common_feat * attention
        return refined_common_feat

class CMAFF(nn.Module):
    def __init__(self, in_channels=512):
        super(CMAFF, self).__init__()
        self.differential_module = DifferentialEnhanciveModule(in_channels)
        self.common_module = CommonSelectiveModule(in_channels)
        self.conv1x1 = nn.Conv2d(in_channels * 2, in_channels, kernel_size=1)

    def forward(self, rgb_feat, ir_feat):
        diff_feat = (rgb_feat - ir_feat) / 2
        common_feat = (rgb_feat + ir_feat) / 2
        enhanced_diff_feat = self.differential_module(diff_feat)
        refined_common_feat = self.common_module(common_feat)
        fused_feat = torch.cat((enhanced_diff_feat, refined_common_feat), dim=1)
        fused_feat = self.conv1x1(fused_feat)
        return fused_feat

class YOLOv5WithCMAFF(nn.Module):
    def __init__(self, yolo_model):
        super(YOLOv5WithCMAFF, self).__init__()
        self.backbone = yolo_model.model.model.model[:10]
        self.ir_conv = nn.Conv2d(3, 512, kernel_size=3, stride=1, padding=1)
        self.ir_downsample = nn.MaxPool2d(kernel_size=32, stride=32)
        self.cmaff = CMAFF(512)

        self.head = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1)
        )

    def forward(self, img):
        rgb_img, ir_img = img[:, :3, :, :], img[:, 3:, :, :]
        rgb_feat = self.backbone(rgb_img)
        ir_feat = self.ir_conv(ir_img)
        ir_feat = self.ir_downsample(ir_feat)
        fused_feat = self.cmaff(rgb_feat, ir_feat)
        for i, layer in enumerate(self.head):
            fused_feat = layer(fused_feat)
        return fused_feat
    
from yolov5.models.yolo import Model
# yolo_model = Model(cfg='yolov5//models//yolov5s.yaml', ch=3, nc=80)
# model = YOLOv5WithCMAFF(yolo_model)
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model = YOLOv5WithCMAFF(yolo_model).to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
# Out:
# Using cache found in C:\Users\Tejaswa/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  v7.0-376-gbcd88eaf Python-3.12.3 torch-2.4.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
for param in model.backbone.parameters():
    param.requires_grad = False
import torch
import torch.optim as optim
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)
classification_loss_fn = nn.BCEWithLogitsLoss()
bbox_loss_fn = nn.SmoothL1Loss()
confidence_loss_fn = nn.BCEWithLogitsLoss()

num_classes = 80
grid_size = (5, 5)

num_epochs = 20
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for imgs, targets in train_loader:
        imgs = imgs.to(device).float()

        optimizer.zero_grad()

        
        outputs = model(imgs)
        print(f"Model output type: {type(outputs)}, output shape: {outputs.shape}")

        class_preds = outputs[:, :num_classes, :, :]
        bbox_preds = outputs[:, num_classes:, :, :]

        bbox_coords_preds = bbox_preds[:, :4, :, :]
        conf_preds = bbox_preds[:, 4:, :, :]

        batch_classification_loss = 0.0
        batch_bbox_loss = 0.0
        batch_confidence_loss = 0.0

        for i, target in enumerate(targets):
            class_target = target[:, 0]
            bbox_target = target[:, 1:].to(device)

            bbox_target_grid = torch.zeros_like(bbox_coords_preds[i])
            class_target_grid = torch.zeros((num_classes, *grid_size)).to(device)

            for obj in target:
                class_label = int(obj[0])
                bbox = obj[1:]

                grid_x = int(bbox[0] * grid_size[0])
                grid_y = int(bbox[1] * grid_size[1])

                grid_x = min(grid_x, grid_size[0] - 1)
                grid_y = min(grid_y, grid_size[1] - 1)

                class_target_grid[class_label, grid_x, grid_y] = 1
                bbox_target_grid[:, grid_x, grid_y] = bbox


            classification_loss = classification_loss_fn(class_preds[i], class_target_grid)

            bbox_loss = bbox_loss_fn(bbox_coords_preds[i], bbox_target_grid)

            confidence_target = torch.ones_like(conf_preds[i]) if target.size(0) > 0 else torch.zeros_like(conf_preds[i])

            confidence_loss = confidence_loss_fn(conf_preds[i], confidence_target)

            print(confidence_loss)

            batch_classification_loss += classification_loss
            batch_bbox_loss += bbox_loss
            batch_confidence_loss += confidence_loss

        total_loss = batch_classification_loss + batch_bbox_loss + batch_confidence_loss

        total_loss.backward()
        optimizer.step()

        running_loss += total_loss.item()
        print(f"Epoch [{epoch+1}/{num_epochs}]")

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader)}")
# Out:
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.69308, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69306, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69311, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.69307, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.68815, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68813, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.68827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.67486, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.67419, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.67805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.67507, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.63450, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.63317, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.63696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.63286, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.56065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.55610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.55623, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.55727, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.41362, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.39066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.38450, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.41605, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.21593, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.20915, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.20693, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.22851, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.08446, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.07319, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.07796, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.06832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02469, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01657, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02003, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00974, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00891, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00931, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00930, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00472, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00479, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00627, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00493, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00426, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00300, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00389, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00370, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00237, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00244, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00189, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00306, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00297, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00368, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01750, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00303, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00326, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00472, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00413, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00416, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00464, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00500, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00475, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00537, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00536, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00491, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00525, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00908, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00629, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00714, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01080, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01283, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01124, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01171, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01168, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01421, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01242, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01082, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01503, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01872, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01620, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02145, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01710, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02230, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02497, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02301, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02627, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02689, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.03169, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02248, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.03416, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01971, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02623, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02981, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02987, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02504, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.02307, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01813, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02245, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.04020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01629, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01682, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01537, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01583, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.01968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.02626, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01437, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00957, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01158, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.01084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00574, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00747, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00853, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00572, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00632, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00537, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00470, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00429, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00374, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00308, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00476, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00347, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00321, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00517, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00362, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00245, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00250, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00222, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00222, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00163, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00214, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00167, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00116, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00200, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00114, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00138, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00137, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00125, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00155, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00118, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00135, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00264, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00167, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00146, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00112, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00119, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00103, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00080, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00091, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00068, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00056, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00124, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00077, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00318, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00075, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00080, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00080, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00064, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00068, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00076, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00058, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00117, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00096, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00106, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00058, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00065, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00111, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00045, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00063, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00087, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00080, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00045, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00084, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00049, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00038, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00050, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00046, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00045, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00062, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00282, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.72152e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00041, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.76983e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.25246e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00030, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00034, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00013, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00013, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [1/20]
# Epoch [1/20], Loss: 0.4424219746313511
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00023, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00028, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00025, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [2/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00017, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# ...
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.69715e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.32827e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.10099e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.96377e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.01371e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.81837e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.66773e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.13568e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.93758e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.85707e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.74599e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.17187e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(7.34562e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.08113e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.75791e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.59939e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.29036e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.82876e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.28321e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.61216e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.48559e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.14810e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.43278e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.02805e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(6.05270e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.80498e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.02953e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.30124e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.51587e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.95093e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.13071e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.21274e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.87708e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.11882e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.00013, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.69698e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.22892e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.01215e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.38911e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.25106e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.23482e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.68612e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.39856e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.90057e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.13492e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.74693e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.66848e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.49689e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.73987e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.19258e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.73002e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.31431e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.00591e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.51882e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.08400e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.64426e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.41872e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.24388e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.38989e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.35182e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.01901e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.36700e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.12161e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.60245e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.01724e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.08405e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.33863e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.15850e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.14886e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.26590e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.43027e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.74404e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.14025e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.95307e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.73273e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.32144e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.32887e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.11293e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.33956e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(8.94886e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.20441e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.66278e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.80804e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.22801e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.72000e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.88576e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.52302e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.12108e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.16661e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.94270e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.95003e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.09472e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.17226e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.22355e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.38145e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.08430e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.10617e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.46415e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.48335e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(9.24390e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.54600e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.02292e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.62031e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.07519e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(8.52908e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.51607e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(9.11870e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.29471e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.32414e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.69976e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.50840e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.06274e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.82811e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.22375e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.36032e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.78028e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.06578e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.52171e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(6.62870e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.77906e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.89279e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.68046e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.45131e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(4.40916e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.52655e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.39319e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.22047e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(3.31410e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.76841e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.47986e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.80612e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(1.86793e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(7.35375e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.79195e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(5.83336e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(2.47816e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(4.69327e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.01511e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(3.61465e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Model output type: <class 'torch.Tensor'>, output shape: torch.Size([4, 512, 5, 5])
# tensor(5.63114e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.47963e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(2.16400e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.67804e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# Epoch [20/20]
# Epoch [20/20], Loss: 0.03563501591871091

# %%
val_data = VEDAIDataset(img_dir="images-Aditya\\images\\val", label_dir="labels-Aditya\\labels\\val", img_size=640)

# %%
val_loader = DataLoader(val_data, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
import torch
from collections import defaultdict
import numpy as np
from sklearn.metrics import precision_recall_curve

def calculate_iou(box1, box2):

    box1_x1 = (box1[0] - box1[2] / 2)
    box1_y1 = (box1[1] - box1[3] / 2)
    box1_x2 = (box1[0] + box1[2] / 2)
    box1_y2 = (box1[1] + box1[3] / 2)
    
    box2_x1 = box2[0] - box2[2] / 2
    box2_y1 = box2[1] - box2[3] / 2
    box2_x2 = box2[0] + box2[2] / 2
    box2_y2 = box2[1] + box2[3] / 2

    inter_x1 = torch.max(box1_x1, box2_x1)
    inter_y1 = torch.max(box1_y1, box2_y1)
    inter_x2 = torch.min(box1_x2, box2_x2)
    inter_y2 = torch.min(box1_y2, box2_y2)
    
    inter_area = max(((inter_x2 - inter_x1)*(inter_y2 - inter_y1)), 0)

    box1_area = (box1_x2 - box1_x1) * (box1_y2 - box1_y1)
    box2_area = (box2_x2 - box2_x1) * (box2_y2 - box2_y1)
    union_area = box1_area + box2_area - inter_area

    iou = (inter_area / (union_area + 1e-6))

    return iou

from torchvision.ops import nms

def apply_nms(predictions, iou_threshold=0.2):
    boxes = predictions[:, :4]
    scores = predictions[:, 4]
    
    keep_indices = nms(boxes, scores, iou_threshold)
    
    return predictions[keep_indices]

def calculate_ap(precision, recall):
    precision = np.concatenate(([0.0], precision, [0.0]))
    recall = np.concatenate(([0.0], recall, [1.0]))

    for i in range(len(precision) - 1, 0, -1):
        precision[i - 1] = max(precision[i - 1], precision[i])

    indices = np.where(recall[1:] != recall[:-1])[0]
    ap = np.sum((recall[indices + 1] - recall[indices]) * precision[indices + 1])
    return ap

def evaluate_model(model, dataloader, iou_threshold=0.1, max_boxes=4):
    model.eval()
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    true_positives_list = []
    scores_list = []
    num_gts = 0

    all_detections = []
    all_ground_truths = []

    with torch.no_grad():
        for imgs, targets in dataloader:
            print(f"precision = ", true_positives / (true_positives + false_positives + 1e-6))
            print(f"recall = ", true_positives / (true_positives + false_negatives + 1e-6))
            p = np.cumsum(true_positives_list) / (np.arange(len(true_positives_list)) + 1)
            r = np.cumsum(true_positives_list) / (num_gts+1)
            print(f"map = ", calculate_ap(p, r))
            imgs = imgs.to(device).float()
            outputs = model(imgs)

            class_preds = outputs[:, :num_classes, :, :]
            bbox_preds = outputs[:, num_classes:, :, :]

            for i, target in enumerate(targets):
                gt_boxes = target[:, 1:]
                pred_boxes = bbox_preds[i].detach().cpu()

                pred_scores = class_preds[i].detach().cpu().view(-1)
                pred_boxes = pred_boxes.view(-1, 4)
                
                if len(pred_scores) > 0:
                    top_indices = torch.topk(pred_scores, min(max_boxes, len(pred_scores))).indices
                    pred_boxes = pred_boxes[top_indices]

                all_ground_truths.append(gt_boxes)
                all_detections.append(pred_boxes)

                matched_gt = set()
                for pred_box in pred_boxes:
                    best_iou = 0
                    best_gt_idx = -1

                    for gt_idx, gt_box in enumerate(gt_boxes):
                        iou = calculate_iou(pred_box, gt_box)
                        iou_value = iou.item()

                        if iou_value > best_iou:
                            best_iou = iou_value
                            best_gt_idx = gt_idx

                    if best_iou > iou_threshold:
                        if best_gt_idx not in matched_gt:
                            true_positives += 1
                            matched_gt.add(best_gt_idx)
                            true_positives_list.append(1)
                    else:
                        false_positives += 1
                        true_positives_list.append(0)

                    scores_list.append(pred_scores[i].item())

                false_negatives += len(gt_boxes) - len(matched_gt)
                num_gts += len(gt_boxes)

    precision = true_positives / (true_positives + false_positives + 1e-6)
    recall = true_positives / (true_positives + false_negatives + 1e-6)

    true_positives_list = np.array(true_positives_list)
    scores_list = np.array(scores_list)

    precisions = np.cumsum(true_positives_list) / (np.arange(len(true_positives_list)) + 1)
    recalls = np.cumsum(true_positives_list) / num_gts

    ap_0_5 = calculate_ap(precisions, recalls)

    return precision, recall, ap_0_5

precision, recall, map_0_5 = evaluate_model(model, val_loader)
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, mAP@0.5: {map_0_5:.4f}")
# Out:
# precision =  0.0
# recall =  0.0
# map =  0.0
# precision =  0.799999840000032
# recall =  0.24999998437500096
# map =  0.2
# precision =  0.7999999200000081
# recall =  0.19512194646044034
# map =  0.1639455782312925
# precision =  0.7058823114186875
# recall =  0.22641509006763982
# map =  0.18626413528374317
# precision =  0.7619047256235845
# recall =  0.23529411418685128
# map =  0.1911663216011042
# precision =  0.7999999680000013
# recall =  0.24999999687500005
# map =  0.20517342739564964
# precision =  0.7741935234131121
# recall =  0.2758620657946889
# map =  0.2283820346320346
# precision =  0.717948699539777
# recall =  0.2718446575549062
# map =  0.2234300840918488
# precision =  0.6808510493435947
# recall =  0.26890756076548267
# map =  0.2164227103792185
# precision =  0.7058823391003464
# recall =  0.24161073663348498
# map =  0.1925585837938779
# precision =  0.6896551605231869
# recall =  0.24390243753718027
# map =  0.1922641754419983
# precision =  0.6874999892578127
# recall =  0.2558139520010817
# map =  0.19926930027705037
# precision =  0.676056328506249
# recall =  0.26086956379962195
# map =  0.20096115837860756
# precision =  0.6341463337299228
# recall =  0.27225130747512405
# map =  0.20774491741079043
# precision =  0.6292134760762531
# recall =  0.2871794857067719
# map =  0.21657467830954397
# precision =  0.6315789407202217
# recall =  0.2884615370747042
# map =  0.21526482666944424
# precision =  0.6274509742406768
# recall =  0.271186439528871
# map =  0.20042855567287662
# precision =  0.6296296237997258
# recall =  0.27755101927530196
# map =  0.20349814455519197
# precision =  0.6050420117223361
# recall =  0.2748091592564536
# map =  0.19984084710972527
# precision =  0.5984251921383843
# recall =  0.2763636353586777
# map =  0.19914837874330443
# precision =  0.5925925882030179
# recall =  0.28070175340104647
# map =  0.20048776228308623
# precision =  0.5957446766259243
# recall =  0.2847457617466245
# map =  0.20179361479716396
# precision =  0.5866666627555556
# recall =  0.2838709668262227
# map =  0.1997783172678111
# precision =  0.5935483832674298
# recall =  0.2902208192737514
# map =  0.20293845082868855
# precision =  0.6024844683075499
# recall =  0.2930513586312648
# map =  0.2036930826879025
# precision =  0.6084337312744956
# recall =  0.29190751360720374
# map =  0.2026214926264348
# precision =  0.6140350841284498
# recall =  0.2916666658564815
# map =  0.20172105452796288
# precision =  0.6193181782993286
# recall =  0.29539295312901637
# map =  0.2043697174096051
# precision =  0.6141304314449433
# recall =  0.2989417981509476
# map =  0.20601756114104325
# precision =  0.6190476157722349
# recall =  0.30154639097539593
# map =  0.2071249298237555
# precision =  0.6142131948517097
# recall =  0.30174563515774155
# map =  0.2066918844220007
# precision =  0.6127450950355633
# recall =  0.30413625230137165
# map =  0.2076609978865443
# precision =  0.6084905631674974
# recall =  0.3100961531007304
# map =  0.2110479077857284
# precision =  0.607305933299973
# recall =  0.310023309300645
# map =  0.2103167471882349
# precision =  0.6088888861827161
# recall =  0.312785387413732
# map =  0.21163523767406595
# precision =  0.6130434755954631
# recall =  0.3098901092090327
# map =  0.2091719057680504
# precision =  0.6170212739701223
# recall =  0.3078556256733426
# map =  0.20755800282018583
# precision =  0.6157024767946179
# recall =  0.31106471751343484
# map =  0.20925084661827265
# precision =  0.6219512169839382
# recall =  0.3116089606688209
# map =  0.2093506181810127
# precision =  0.6230158705435879
# recall =  0.30905511750186
# map =  0.2076550071044343
# precision =  0.6240310053332132
# recall =  0.31021194545238545
# map =  0.20806918784604306
# Precision: 0.6255, Recall: 0.3098, mAP@0.5: 0.2082
